# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("P_ES50_d_cleaned_Nov_2020.csv", parse_dates=True, index_col=0)

# %%
data.describe()
# Out:
#             ADS.DE        AI.PA       ALV.DE      ASML.AS       BAS.DE  \
# count  5379.000000  5379.000000  5379.000000  5379.000000  5379.000000
# mean     70.016283    51.488699    95.209724    61.042165    32.914468
# std      73.367399    33.540159    51.145748    69.975295    21.701407
# min       6.420244     7.866548    21.141090     3.916246     5.241868
# 25%      21.300701    18.973166    50.714615    15.131855    11.496277
# 50%      36.702938    44.144810    78.907974    29.637903    27.360588
# 75%      76.123608    77.576603   140.304466    81.714249    52.954926
# max     309.818024   142.750000   218.202454   352.140381    78.570663
#
#            BAYN.DE      BBVA.MC       BMW.DE        BN.PA       BNP.PA  ...  \
# count  5379.000000  5379.000000  5379.000000  5379.000000  5379.000000  ...
# mean     46.516540     5.261107    39.528800    36.060871    31.020087  ...
# std      28.348632     1.333252    22.684189    16.611168    10.074476  ...
# ...

# %%
data.head()
# Out:
#               ADS.DE      AI.PA      ALV.DE    ASML.AS    BAS.DE    BAYN.DE  \
# Date
# 2000-01-03  9.737806  10.226519  145.655563  28.812193  8.069616  25.103666
# 2000-01-04  9.394521   9.772677  145.655563  27.428837  7.841083  24.090979
# 2000-01-05  9.171777   9.681908  144.967438  24.812944  7.541625  23.451403
# 2000-01-06  9.564853  10.377778  150.931305  23.077412  7.569995  23.531343
# 2000-01-07  9.433829  10.250728  155.128922  24.800396  7.880485  24.512018
#
#              BBVA.MC     BMW.DE      BN.PA     BNP.PA  ...     SAN.PA  \
# Date                                                   ...
# 2000-01-03  5.028991  12.766329  10.262662  16.221174  ...  19.691515
# 2000-01-04  4.897759  12.251177   9.818396  15.765247  ...  18.466921
# 2000-01-05  4.787792  12.008748   9.773990  15.432045  ...  17.688078
# 2000-01-06  4.817951  11.969790  10.484813  14.905943  ...  18.368954
# 2000-01-07  4.848111  11.948142  10.529222  15.098841  ...  19.348635
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
r_d = np.log(data/data.shift())
r_d = r_d.dropna()
r_d.head()
# Out:
# C:\Users\mralb\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
#               ADS.DE     AI.PA    ALV.DE   ASML.AS    BAS.DE   BAYN.DE  \
# Date
# 2000-01-05 -0.023996 -0.009332 -0.004736 -0.100229 -0.038939 -0.026907
# 2000-01-06  0.041964  0.069408  0.040316 -0.072511  0.003755  0.003403
# 2000-01-07 -0.013793 -0.012318  0.027432  0.072005  0.040197  0.040830
# 2000-01-10  0.015025 -0.035451  0.005750  0.069533  0.004390  0.035670
# 2000-01-11 -0.009347 -0.009217 -0.009157  0.012224 -0.045421 -0.030031
#
#              BBVA.MC    BMW.DE     BN.PA    BNP.PA  ...    SAN.PA    SAP.DE  \
# Date                                                ...
# 2000-01-05 -0.022709 -0.019987 -0.004533 -0.021362  ... -0.043090 -0.128606
# 2000-01-06  0.006280 -0.003249  0.070203 -0.034686  ...  0.037771  0.031925
# ...

# %%
r_d.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
r_d["ADS.DE"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
w_eq = [1/r_d.shape[1] for i in range(r_d.shape[1])]

# %%
r_d["1/N"] = r_d.dot(w_eq)

# %%
r_d.describeribe()
# Out:
#             ADS.DE        AI.PA       ALV.DE      ASML.AS       BAS.DE  \
# count  5375.000000  5375.000000  5375.000000  5375.000000  5375.000000
# mean      0.000615     0.000495     0.000033     0.000463     0.000355
# std       0.019150     0.015686     0.021546     0.027999     0.018298
# min      -0.166886    -0.118337    -0.166382    -0.233179    -0.146707
# 25%      -0.008545    -0.007436    -0.008742    -0.012111    -0.008613
# 50%       0.000000     0.000556     0.000343     0.000480     0.000435
# 75%       0.009603     0.008400     0.009122     0.013044     0.009400
# max       0.162592     0.112783     0.233053     0.210160     0.176407
#
#            BAYN.DE      BBVA.MC       BMW.DE        BN.PA       BNP.PA  ...  \
# count  5375.000000  5375.000000  5375.000000  5375.000000  5375.000000  ...
# mean      0.000117    -0.000119     0.000304     0.000300     0.000147  ...
# std       0.020408     0.021647     0.020720     0.014754     0.023612  ...
# ...

# %%
InvOpp = r_d.agg(["mean", "std"]).T

# %%
InvOpp["SR"] = InvOpp["mean"]/InvOpp["std"]

# %%
InvOpp["mean"] = InvOpp["mean"] * 252
InvOpp["std"] = InvOpp["std"] * np.sqrt(252)
InvOpp["SR"] = InvOpp["SR"] * np.sqrt(252)

# %%
InvOpp.describe()
# Out:
#             mean        std         SR
# count  44.000000  44.000000  44.000000
# mean    0.051581   0.344550   0.171527
# std     0.057420   0.122154   0.194377
# min    -0.097401   0.219495  -0.218723
# 25%     0.028922   0.286760   0.070147
# 50%     0.054341   0.327761   0.145558
# 75%     0.085335   0.361049   0.283984
# max     0.164334   1.025568   0.556171

# %%
InvOpp.plot(kind="scatter", x = "std", y="mean", figsize=(15,15))

for name in r_d:
    plt.annotate(name, xy=(InvOpp.loc[name,'std']+0.002, InvOpp.loc[name,'mean']+0.002))

# %%
r_d["SAP.DE"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
r_d["SAP.DE"][np.abs(r_d["SAP.DE"])>1.0] = r_d["SAP.DE"].mean()

# %%
r_d["SAP.DE"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
InvOpp["SR"] = InvOpp["mean"]/InvOpp["std"]
InvOpp["mean"] = InvOpp["mean"] * 252
InvOpp["std"] = InvOpp["std"] * np.sqrt(252)
InvOpp["SR"] = InvOpp["SR"] * np.sqrt(252)
